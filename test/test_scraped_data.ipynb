# %%
import pandas as pd
import datetime as dt
from datetime import datetime

# %%
data = pd.read_csv("/home/xena/Desktop/prateek/oneGo/onego_poc1/files/scraped_data/paytm_flights_50_schedule.csv", sep =",")
# Out:
# /home/xena/miniconda3/envs/onego/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.loc[data.Dept_Date == '2019-11-15']
# Out:
#                  RecordDate    Airline     Flight   Dept_Date Dept_Time  \
# 236761  2019-09-01 23:47:19        NaN        NaN  2019-11-15       NaN
# 236762  2019-09-01 23:47:31        NaN        NaN  2019-11-15       NaN
# 236763  2019-09-01 23:47:44        NaN        NaN  2019-11-15       NaN
# 236764  2019-09-01 23:47:56        NaN        NaN  2019-11-15       NaN
# 236765  2019-09-01 23:48:09        NaN        NaN  2019-11-15       NaN
# 236766  2019-09-01 23:48:21        NaN        NaN  2019-11-15       NaN
# 236767  2019-09-01 23:48:34        NaN        NaN  2019-11-15       NaN
# 236768  2019-09-01 23:48:46        NaN        NaN  2019-11-15       NaN
# 236769  2019-09-01 23:48:59        NaN        NaN  2019-11-15       NaN
# 236770  2019-09-01 23:49:12        NaN        NaN  2019-11-15       NaN
# 236771  2019-09-01 23:49:25        NaN        NaN  2019-11-15       NaN
# 236772  2019-09-01 23:49:37        NaN        NaN  2019-11-15       NaN
# ...

# %%
data.columns
# Out:
# Index(['RecordDate', 'Airline', 'Flight', 'Dept_Date', 'Dept_Time', 'Origin',
#        'Duration', 'Stops', 'Arr_Date', 'Arr_Time', 'Destination',
#        'Total_Fare', 'dummy_comma1', 'dummy_comma2'],
#       dtype='object')

# %%
data['Dept_Date'] = pd.to_datetime(data.Dept_Date, errors ='coerce')

# %%
data['RecordDate'] = pd.to_datetime(data.RecordDate, errors ='coerce')

# %%
data.shape
# Out:
# (513519, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513519 entries, 0 to 513518
# Data columns (total 14 columns):
# RecordDate      513506 non-null datetime64[ns]
# Airline         508842 non-null object
# Flight          508842 non-null object
# Dept_Date       513506 non-null datetime64[ns]
# Dept_Time       508842 non-null object
# Origin          513519 non-null object
# Duration        508842 non-null object
# Stops           508842 non-null object
# Arr_Date        13 non-null object
# Arr_Time        508842 non-null object
# Destination     513519 non-null object
# Total_Fare      508842 non-null object
# dummy_comma1    2808 non-null object
# dummy_comma2    2808 non-null object
# dtypes: datetime64[ns](2), object(12)
# memory usage: 54.8+ MB

# %%
data.groupby(['Dept_Date']).count()
# Out:
#             RecordDate  Airline  Flight  Dept_Time  Origin  Duration  Stops  \
# Dept_Date
# 2019-11-10       48160    47828   47828      47828   48160     47828  47828
# 2019-11-11       46673    46348   46348      46348   46673     46348  46348
# 2019-11-12       46096    45719   45719      45719   46096     45719  45719
# 2019-11-13       48333    47981   47981      47981   48333     47981  47981
# 2019-11-14       47494    47132   47132      47132   47494     47132  47132
# 2019-11-15       40392    39712   39712      39712   40392     39712  39712
# 2019-11-16       42427    42084   42084      42084   42427     42084  42084
# 2019-11-17       46047    45644   45644      45644   46047     45644  45644
# 2019-11-18       36973    36765   36765      36765   36973     36765  36765
# 2019-11-19       37993    37381   37381      37381   37993     37381  37381
# 2019-11-20       46714    46319   46319      46319   46714     46319  46319
# ...
